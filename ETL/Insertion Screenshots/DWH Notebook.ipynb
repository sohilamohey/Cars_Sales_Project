-- %%
select * from [Car_DWs].[dbo].[Dim_Car]
-- Out:
-- (883 rows affected)
-- Total execution time: 00:00:00.071
-- ...

-- %%
select * from Dim_Customer
-- Out:
-- (1000 rows affected)
-- Total execution time: 00:00:00.022
-- ...

-- %%
select * from Dim_Shipping_method
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>shipping_sk</th><th>shipping_id_bk</th><th>shipping</th><th>ship_mode</th><th>ship_cost</th><th>source_code</th></tr><tr><td>1201</td><td>1</td><td>Truck</td><td>Standard Class</td><td>500</td><td>1</td></tr><tr><td>1202</td><td>2</td><td>Truck</td><td>First Class</td><td>1300</td><td>1</td></tr><tr><td>1203</td><td>3</td><td>Truck</td><td>Second Class</td><td>800</td><td>1</td></tr><tr><td>1204</td><td>4</td><td>Air</td><td>Standard Class</td><td>1000</td><td>1</td></tr><tr><td>1205</td><td>5</td><td>Air</td><td>First Class</td><td>300</td><td>1</td></tr><tr><td>1206</td><td>6</td><td>Air</td><td>Second Class</td><td>1500</td><td>1</td></tr><tr><td>1207</td><td>7</td><td>Air</td><td>Same Day</td><td>4000</td><td>1</td></tr><tr><td>1208</td><td>8</td><td>Truck</td><td>Same Day</td><td>3000</td><td>1</td></tr></table>

-- %%
select * from Dim_Supplier
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.014
-- ...

-- %%
select * from Dim_Supplier
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:00.011
-- ...

-- %%
select * from Fact_Sales
-- Out:
-- (1000 rows affected)
-- Total execution time: 00:00:00.047
-- ...
